# %% [markdown]
# # Creacion de diagramas de caja

# %%
import numpy as np
import matplotlib.pyplot as plt

edades = np.array([10, 20, 30, 40, 50, 60, 70, 80])
plt.yticks(np.arange(0, 100, 5))
plt.grid(True)
plt.boxplot(edades)
plt.show()

# %%
(np.min(edades), np.quantile(edades, 0.25), np.median(edades), np.quantile(edades, 0.75), np.max(edades))
# Out:
# (np.int64(10),
#  np.float64(27.5),
#  np.float64(45.0),
#  np.float64(62.5),
#  np.int64(80))

# %% [markdown]
# # Datos anomalos - Prueba de Tukey

# %%
edades = np.array([6, 41, 51, 51, 52, 54, 57, 60, 61, 65, 95, 100])
plt.grid(True)
plt.yticks(np.arange(0, 110, 5))
plt.boxplot(edades)
plt.show()
